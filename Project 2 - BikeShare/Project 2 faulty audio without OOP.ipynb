# %% [markdown]
# ## Notes

# %% [markdown]
# (1) Add more questions for single categories.
# (2) Combine the features, such as the trip duration data for each month on a bar graph, the max for each month, the minimums, the averages. Combine 3 features.
# Which month has the longest trip duration? The shortest trip duration?
# (2) Combine the totals in each category for every city, and give the option to see collective for all cities combined.
# (3) Data visualizations: (a) Pie charts showing a percentile comparison between genders and user types. (a.i) for New York and Chicago individually (a.ii)the total users (2) Histogram showing (bar graph?) showing the number of users for each month (3)Consider scatter plots

# %% [markdown]
# # References

# %% [markdown]
# Python Tutorial: https://docs.python.org/3/tutorial/errors.html for errors and exceptions
#
# StackOverflow: https://stackoverflow.com/questions/40278845/suppress-name-dtype-from-python-pandas-describe for displaying df.value_counts() without the name and dtype
#
# StackOverflow: https://stackoverflow.com/questions/6557553/get-month-name-from-number from number to month to avoid conditional lines of code
#
# Speech-Text in Python: https://www.youtube.com/watch?v=jc_-AIYvfKs&t=1s
#
# Text-Speech in python: https://pythonprogramminglanguage.com/text-to-speech/
#
# Playing mp3 file in python: https://stackoverflow.com/questions/20021457/playing-mp3-song-on-python
#
# Converting months to abbreviated names for the bar graph: https://stackoverflow.com/questions/37625334/python-pandas-convert-month-int-to-month-name
#
# to rename the fist user column from 'Unnamed: 0' to 'User Id': https://stackoverflow.com/questions/11346283/renaming-columns-in-pandas

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import speech_recognition as sr
import time
import pandas as pd
import numpy as np
import calendar
import subprocess
#import pygame
from pygame import mixer
#import IPython.display as ipd
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def tts(text, filename):
    from gtts import gTTS
    import os
    from pygame import mixer # Load the required librarya
    tts = gTTS(text='%s' % text, lang='en')
    tts.save("%s.mp3" % filename)
    mp3file = os.system("mpg321 %s.mp3" % filename)
    return mp3file4


def play_mp3file(filename):
    mixer.init()
    mixer.music.load('%s.mp3' % filename)
    play_mp3 = mixer.music.play()
    return play_mp3

def audio_input():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        audio = r.listen(source)
        audio_input = r.recognize_google(audio)
    return audio_input

#city_selection = tts("Choose which city to explore. Say 1 for Chicago, 2 for New York City, or 3 for Washington", 'city_selection')
#month_selection = tts("Choose which month. Say 1 for January, 2 for February, 3 for March, 4 for April, 5 for May, or 6 for June. Say 7 if you want data from all months.", 'month_selection')
#day_selection = tts('Choose the day. Say 0 for monday, 1 for tuesday, 2 for wednesday, 3 for thursday, 4 for friday, 5 for saturday, or 6 for sunday. Say 7 for all days.', 'day_selection')

# %%
city_data = { '1': 'chicago.csv',
                 '2': 'new_york_city.csv',
                  '3': 'washington.csv' }
def get_filters():
    global city, month, day
    """
    Asks user to specify a city, month, and day to analyze.

    """
    print('Hello! Let\'s explore some US bikeshare data!')
    print()
    
    err_msg = 'Invalid input, try again...'
    # TO DO: get user input for city (chicago, new york city, washington). HINT: Use a while loop to handle invalid inputs
   
    #city = input("Choose your city: Chicago, Washington, or New York: ") if placed here instead of inside the while loop: infinite loop and crash!
    cities = ['1','2','3']
    while True:
        count = 0 
        while count < 3: 
            try:
                city_selection
                #subprocess.call('city_selection.mp3', shell=True)#print('SAY integer to explore one of three cities: Chicago=1, New York=2, Washington=3: ')
                city = audio_input()
                count += 1
                print('You likely said', city)
                if city not in cities:
                    print(err_msg)
                else:
                    print()
                    if city == '1': print('You chose Chicago...')
                    elif city == '2': print('You chose New York City...')
                    elif city == '3':print('You chose Washington...')
                    break
            except:
                city = ''
                print('Try again...')
                count += 1
        #while True:
        if city in cities:
            break
        else:
            try:
                city = input("Choose your city: Chicago=1, New York=2, Washington=3: ")
                if city not in cities:
                    print(err_msg)
                else:
                    print()
                    if city == '1': print('You chose Chicago...')
                    elif city == '2': print('You chose New York City...')
                    elif city == '3':print('You chose Washington...')
                    break
            except:
                print('Try again...')
   
    # TO DO: get user input for month (all, january, february, ... , june)
    months = ['1','2','3','4','5','6','7']
    print()
    while True:
        count = 0
        while count < 3:
            try:
                month_selection
                #subprocess.call('month_selection.mp3', shell = True)#print('Say the integer of the month you wish to explore (Jan=1, Feb=2...June=6, All months = 7): ')
                month  = audio_input()
                count +=1
                print('You likely said', month)
                if month not in months:
                    print(err_msg)
                else:
                    if month != str(7):
                        print()
                        print('You chose', calendar.month_name[int(month)])
                    break
            except:
                month = ''
                print('Try again...')
                count += 1
        
        if month in months:
            break
        else:
            try:
                month = input("Which month (Jan = 1, Feb = 2...)? If all months, type 7: ")
                if month not in months:
                    print(err_msg)
                else:
                    if month != str(7):
                        print()
                        print('You chose', calendar.month_name[int(month)])
                    break
            except: 
                print('Try again...')
            
    # TO DO: get user input for day of week (all, monday, tuesday, ... sunday)
    days = ['0','1','2','3','4','5','6','7']
    print()
    while True:
        count = 0
        while count < 3:
            try:
                day_selection
                #subprocess.call('day_selection.mp3', shell=True)
                day  = audio_input()
                count +=1
                print('You likely said', day)
                if day not in days:
                    print(err_msg)
                else:
                    if day != str(7):
                        print()
                        print('You chose', calendar.day_name[int(day)])
                    break
            except:
                day = ''
                print('Try again...')
                count+=1
        
        if day in days:
            break
        else:
            try:
                print()
                day = input("Day of the week (Mon=0, Tue=1, Wed=2, Thu=3, Fri=4, Sat-5, Sunday=6)? If all days, type 7: ")
                if day not in days:
                    print(err_msg)
                else:
                    if day != str(7):
                        print()
                        print('You chose', calendar.day_name[int(day)])
                    break
            except: 
                print('Try again...')

    print('-'*40)
    
    month = int(month)
    day = int(day)
    
    """
    Loads data for the specified city and filters by month and day if applicable.

    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """

    # load data file into a dataframe
    df = pd.read_csv(city_data[city])
    
    #change name of user column to user_id
    column_rename = df.columns.values 
    column_rename[0] = 'User Id'
    df.columns = column_rename

    # convert the Start Time column to datetime
    df['Start Time'] = pd.to_datetime(df['Start Time'])
    df['End Time'] = pd.to_datetime(df['End Time'])

    # extracts month, day of the week, and hour from Start Time to create new columns
    df['month'] = df['Start Time'].dt.month
    df['day_of_week'] = df['Start Time'].dt.dayofweek
    df['start hour'] = df['Start Time'].dt.hour
    df['end hour'] = df['End Time'].dt.hour

    # filter by month if applicable
    if month != 7:
        # use the index of the months list to get the corresponding int
        months = list(range(1,8)) #['jan', 'feb','mar','apr','may','june']
        month = months.index(month) + 1

        # filter by month to create the new dataframe
        df = df[df['month'].values == month]

    # filter by day of week if applicable
    if day != 7:
        # filter by day of week to create the new dataframe
        df = df[df['day_of_week'].values == day]
    
    return city, month, day, df


def time_stats(df):
    """Displays statistics on the most frequent times of travel."""
    print(str('\nCalculating The Most Frequent Times of Travel...\n').upper())
    start_time = time.time()

    # TO DO: display the most common month
    month_mode = df['month'].mode()[0]
        
    month_counts = df['month'].value_counts().reset_index()
    
    if month == 7:
        print(month_counts.to_string(header=None, index=None))
        print()
        print('The most common month:', calendar.month_name[month_mode])
        df['month'] = df['month'].apply(lambda x: calendar.month_abbr[x])
        month_counts = df['month'].value_counts(ascending=True)
        month_counts.plot(title='Number of Users per Month', kind='bar', legend = False)
        plt.show()

    # TO DO: display the most common day of week
    day_mode = df['day_of_week'].mode()[0]
    
    if day == 7:
        print()
        print('The most common day of the week: ', calendar.day_name[day_mode])
        df['day_of_week'] = df['day_of_week'].apply(lambda x: calendar.day_abbr[x])
        day_counts = df['day_of_week'].value_counts(ascending=True)
        day_counts.plot(title='Users per Day', kind='bar', legend = False)
        plt.show()
    
    # TO DO: display the most common start hour
    startHour_mode = df['start hour'].mode()[0]
    print()
    print('The most common start hour of the day: ', startHour_mode)
    print()
    endHour_mode = df['end hour'].mode()[0]
    print('Most common end hour of the day: ', endHour_mode)
    print()
    startHr_min = df['start hour'].min()
    print('Earliest start hour:', startHr_min)
    print()
    startHr_max = df['start hour'].max()
    print('Latest start hour', startHr_max)
    print()
    hour_counts = df['start hour'].value_counts(ascending=True)
    print(hour_counts)
    hour_counts.plot(x = 'hour', title='Users Per Hour', kind='bar', legend = False)
    plt.show()

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def station_stats(df):
    """Displays statistics on the most popular stations and trip."""

    print(str('\nCalculating The Most Popular Stations and Trip...\n').upper())
    start_time = time.time()

    # TO DO: display most commonly used start station
    start_station_mode = df['Start Station'].mode()[0]
    print('Most common start station: ', start_station_mode)
    
    # TO DO: display most commonly used end station
    end_station_mode = df['End Station'].mode()[0]
    print()
    print('Most common end station: ', end_station_mode)
    print()

    # TO DO: display most frequent combination of start station and end station trip
    loc_combo_mode = max(df.groupby(['Start Station', 'End Station']).size().index)
    print('Most frequent combination of Start and End stations -- START: %s, END: %s '  % (loc_combo_mode[0], loc_combo_mode[1]))

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""

    print(str('\nCalculating Trip Duration...\n').upper())
    start_time = time.time()

    # TO DO: display total travel time
    total_time = df['Trip Duration'].sum() 
    print('Total travel time: %s hours %s minutes %s seconds' % (total_time//3600, total_time%3600//60, total_time%3600%60))
    print()
    
    # TO DO: display mean travel time
    time_avg = df['Trip Duration'].mean()
    print('Travel time average: %s seconds' % (time_avg))
    print()
    
    time_max = df['Trip Duration'].max()
    print('Longest trip duration: %s seconds' % (time_max))
    print()
    
    time_min = df['Trip Duration'].min()
    print('Shortest trip duration: %s seconds' % (time_min))
    print()


    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def user_stats(df):
    """Displays statistics on bikeshare users."""

    print(str('\nCalculating User Stats...\n').upper())
    start_time = time.time()

    # TO DO: Display counts of user types 
    user_type = df['User Type'].value_counts().reset_index()
    print('User type counts:\n\n', user_type.to_string(header=None, index=None))
    print()
    user_type_counts = df['User Type'].value_counts()
    subscriber = df['User Type'].value_counts()[0]
    customer = df['User Type'].value_counts()[1]
    percent_subscriber = (subscriber/(subscriber + customer))*100
    percent_customer = (customer/(customer + subscriber))*100
    print('Percentage of users as subscribers: {}%'.format(percent_subscriber))
    print()
    print('Percentage of users as customers: {}%'.format(percent_customer))
    print()
    user_type_counts.plot(kind='pie', title='User Type').set_ylabel('')
    plt.suptitle('')
    plt.show()

    # TO DO: Display counts of gender
    try:
        gender = df['Gender'].value_counts().reset_index()
        print('Gender counts:\n\n ', gender.to_string(header=None, index=None))
        print()
        gender_counts = df['Gender'].value_counts()
        male = gender_counts[0]
        female = gender_counts[1]
        percentage_male = (male/(male + female))*100
        percentage_female = (female/(female + male))*100
        print('Percentage of users as males: %s percent' % (percentage_male))
        print()
        print('Percentage of users as females: %s percent' % (percentage_female))
        print()
        gender_counts.plot(kind='pie', title='Gender').set_ylabel('')
        plt.show()
        print()
        gender_userType = df.groupby(['Gender', 'User Type']).size().reset_index()
        print(gender_userType.to_string(header=None, index=None))
    except KeyError:
        print('Washington has no gender data')
    
    print()
    
    # TO DO: Display earliest, most recent, and most common year of birth
    try:
        birthYear_mode = df['Birth Year'].mode()[0]
        print('Most common birth year: ', int(birthYear_mode))
        print()
        mostRecent_birthYear = df['Birth Year'].max()
        print('Most recent birth year:', int(mostRecent_birthYear))
        print()
        earliest_birthYear = df['Birth Year'].min()
        print('Earliest birth year:', int(earliest_birthYear))
    except KeyError:
        print('Washington has no birth year data')

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def main():
    while True:
        city, month, day, df = get_filters()
        time_stats(df)
        station_stats(df)
        trip_duration_stats(df)
        user_stats(df)
        while True:
            valid_responses = ['Y', 'N']
            restart = input('\nWould you like to restart? Enter Y or N.\n').capitalize()
            if restart not in valid_responses:
                print('Invalid input. Y or N?')
            elif restart == 'Y':
                city, month, day, df = get_filters()
                time_stats(df)
                station_stats(df)
                trip_duration_stats(df)
                user_stats(df)
            elif restart != 'Y':
                play_mp3file('goodbye')
                break
        break
            
if __name__ == "__main__":
	main()
# Out:
# Hello! Let's explore some US bikeshare data!
#
# Try again...
# Try again...
# Try again...
# Choose your city: Chicago=1, New York=2, Washington=3: 1
#
# You chose Chicago...
#
# Try again...
# Try again...
# Try again...
# Which month (Jan = 1, Feb = 2...)? If all months, type 7: 7
#
# Try again...
# Try again...
# Try again...
#
# Day of the week (Mon=0, Tue=1, Wed=2, Thu=3, Fri=4, Sat-5, Sunday=6)? If all days, type 7: 7
# ----------------------------------------
#
# CALCULATING THE MOST FREQUENT TIMES OF TRAVEL...
#
# 6
#
# The most common month: June
# The most common day of the week:  Tuesday
# The most common start hour of the day:  17
#
# Most common end hour of the day:  17
#
# Earliest start hour: 0
#
# Latest start hour 23
#
# 3       372
# 4       467
# 2       609
# 1       982
# 0      1686
# 5      2437
# 23     3014
# 22     4895
# 21     7103
# 6      8246
# 20    10301
# 10    11952
# 9     13691
# 11    15040
# 19    15715
# 12    17467
# 13    17559
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import speech_recognition as sr
import IPython.display as ipd
import time
import pandas as pd
import numpy as np
import calendar
import subprocess
import pygame
from pygame import mixer
import IPython.display as ipd

city_data = { '1': 'chicago.csv',
             '2': 'new_york_city.csv',
              '3': 'washington.csv' }

# %%
chicago = city_data['1']
new_york = city_data['2']
washington = city_data['3']

# %%
df_chicago = pd.read_csv(chicago)
df_chicago['Start Time'] = pd.to_datetime(df_chicago['Start Time'])
df_chicago.columns
# Out:
# Index(['Unnamed: 0', 'Start Time', 'End Time', 'Trip Duration',
#        'Start Station', 'End Station', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')

# %%
df_ny = pd.read_csv(new_york)
print()
print(df_ny.isnull().sum().sum())
df_ny['Start Time'] = pd.to_datetime(df_ny['Start Time'])
df_ny['month'] = df_ny['Start Time'].dt.month
print(df_ny['month'].mode()[0])
df_ny['day of week'] = df_ny['Start Time'].dt.dayofweek
df_ny['day of week'].mode()[0]
df_ny['User Type'].value_counts()
subscriber = df_ny['User Type'].value_counts()[0]
customer = df_ny['User Type'].value_counts()[1]
df_ny.head()
# Out:
# 58121
# 6
#    Unnamed: 0          Start Time             End Time  Trip Duration  \
# 0     5688089 2017-06-11 14:55:05  2017-06-11 15:08:21            795
# 1     4096714 2017-05-11 15:30:11  2017-05-11 15:41:43            692
# 2     2173887 2017-03-29 13:26:26  2017-03-29 13:48:31           1325
# 3     3945638 2017-05-08 19:47:18  2017-05-08 19:59:01            703
# 4     6208972 2017-06-21 07:49:16  2017-06-21 07:54:46            329
#
#              Start Station             End Station   User Type  Gender  \
# 0  Suffolk St & Stanton St  W Broadway & Spring St  Subscriber    Male
# 1  Lexington Ave & E 63 St         1 Ave & E 78 St  Subscriber    Male
# 2        1 Pl & Clinton St    Henry St & Degraw St  Subscriber    Male
# 3    Barrow St & Hudson St         W 20 St & 8 Ave  Subscriber  Female
# 4          1 Ave & E 44 St         E 53 St & 3 Ave  Subscriber    Male
#
#    Birth Year  month  day of week
# 0      1998.0      6            6
# 1      1981.0      5            3
# ...

# %%
df_wash = pd.read_csv(washington)
df_wash['Start Time'] = pd.to_datetime(df_wash['Start Time'])
df_wash['month'] = df_wash['Start Time'].dt.month
print(df_wash['month'].mode()[0])
df_wash['day of week'] = df_wash['Start Time'].dt.dayofweek
df_wash['day of week'].mode()[0]
df_wash
# Out:
# 6
#         Unnamed: 0          Start Time             End Time  Trip Duration  \
# 0          1621326 2017-06-21 08:36:34  2017-06-21 08:44:43        489.066
# 1           482740 2017-03-11 10:40:00  2017-03-11 10:46:00        402.549
# 2          1330037 2017-05-30 01:02:59  2017-05-30 01:13:37        637.251
# 3           665458 2017-04-02 07:48:35  2017-04-02 08:19:03       1827.341
# 4          1481135 2017-06-10 08:36:28  2017-06-10 09:02:17       1549.427
# 5          1148202 2017-05-14 07:18:18  2017-05-14 07:24:56        398.000
# 6          1594275 2017-06-19 08:41:43  2017-06-19 09:00:08       1105.429
# 7          1601832 2017-06-20 05:54:42  2017-06-20 06:05:18        636.218
# 8           574182 2017-03-24 20:37:00  2017-03-24 20:42:00        328.530
# 9           327058 2017-02-20 21:12:00  2017-02-20 21:31:00       1188.090
# 10          854729 2017-04-17 02:50:51  2017-04-17 03:05:17        866.689
# ...

# %%
print(max(df_wash.groupby(['Start Station', 'End Station']).size().index))
# Out:
# ('Yuma St & Tenley Circle NW', 'Wisconsin Ave & O St NW')

# %%
print(df_ny.isnull().sum().sum())
print(df_chicago.isnull().sum().sum())
print(df_wash.isnull().sum().sum())
# Out:
# 58121
# 122071
# 0
